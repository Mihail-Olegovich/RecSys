# %%
import ast
import json
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import pickle

import warnings
warnings.filterwarnings('ignore')

from collections import Counter
from random import randint, random
from scipy.sparse import coo_matrix, hstack
from sklearn.metrics.pairwise import euclidean_distances, cosine_distances, cosine_similarity

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
interactions_df = pd.read_csv('/kaggle/input/kion-processed/interactions_processed.csv')
users_df = pd.read_csv('/kaggle/input/kion-processed/users_processed.csv')
items_df = pd.read_csv('/kaggle/input/kion-processed/items_processed.csv')

# %%
interactions_df['t_dat'] = pd.to_datetime(interactions_df['last_watch_dt'], format="%Y-%m-%d")
interactions_df['timestamp'] = interactions_df.t_dat.values.astype(np.int64) // 10 ** 9

# %%
df = interactions_df[['user_id', 'item_id', 'timestamp']].rename(
    columns={'user_id': 'user_id:token', 'item_id': 'item_id:token', 'timestamp': 'timestamp:float'})

# %%
# !mkdir recbox_data

# %%
df.to_csv('recbox_data/recbox_data.inter', index=False, sep='\t')

# %%
import logging
from logging import getLogger
from recbole.config import Config
from recbole.data import create_dataset, data_preparation
from recbole.model.sequential_recommender import GRU4Rec, Caser
from recbole.trainer import Trainer
from recbole.utils import init_seed, init_logger
from recbole.quick_start import run_recbole

# %%
parameter_dict = {
    'data_path': '',
    'USER_ID_FIELD': 'user_id',
    'ITEM_ID_FIELD': 'item_id',
    'TIME_FIELD': 'timestamp',
    'device': 'GPU',
    'user_inter_num_interval': "[40,inf)",
    'item_inter_num_interval': "[40,inf)",
    'load_col': {'inter': ['user_id', 'item_id', 'timestamp']},
    'neg_sampling': None,
    'epochs': 10,
    'eval_args': {
        'split': {'RS': [9, 0, 1]},
        'group_by': 'user',
        'order': 'TO',
        'mode': 'full'}
}
config = Config(model='MultiVAE', dataset='recbox_data', config_dict=parameter_dict)

# init random seed
init_seed(config['seed'], config['reproducibility'])

# logger initialization
init_logger(config)
logger = getLogger()
# Create handlers
c_handler = logging.StreamHandler()
c_handler.setLevel(logging.INFO)
logger.addHandler(c_handler)

# write config info into log
# logger.info(config)

# %%
dataset = create_dataset(config)
logger.info(dataset)
# Out:
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']

# %%
# dataset splitting
train_data, valid_data, test_data = data_preparation(config, dataset)
# Out:
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]

# %%
import time

# %%
# %%time
model_list = ['MultiVAE', 'MultiDAE', 'MacridVAE',
              "NeuMF", "RecVAE", 'RepeatNet']

for model_name in model_list:
    print(f"running {model_name}...")
    start = time.time()
    result = run_recbole(model=model_name, dataset = 'recbox_data',config_dict = parameter_dict)
    t = time.time() - start
    print(f"It took {t/60:.2f} mins")
    print(result)
# Out:
# running MultiVAE...
# ['/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py', '-f', '/tmp/tmp4odlef17.json', '--HistoryManager.hist_file=:memory:']
#
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 10
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# mlp_hidden_size = [600]
# latent_dimension = 128
# dropout_prob = 0.5
# anneal_cap = 0.2
# total_anneal_steps = 200000
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# device = cpu
# neg_sampling = None
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# Max value of user's history interaction records has reached 20.9471766848816% of the total.
# MultiVAE(
#   (encoder): Sequential(
#     (0): Linear(in_features=3294, out_features=600, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=600, out_features=128, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=64, out_features=600, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=600, out_features=3294, bias=True)
#   )
# )
# Trainable parameters: 4072622
# FLOPs: 4068000.0
# Train     0: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.01it/s]
# epoch 0 training [time: 3.49s, train loss: 3249.5872]
# Saving current: saved/MultiVAE-Nov-27-2022_16-35-42.pth
# Train     1: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.13it/s]
# epoch 1 training [time: 3.30s, train loss: 3098.8139]
# Saving current: saved/MultiVAE-Nov-27-2022_16-35-42.pth
# Train     2: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.16it/s]
# epoch 2 training [time: 3.26s, train loss: 3044.8109]
# Saving current: saved/MultiVAE-Nov-27-2022_16-35-42.pth
# Train     3: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.15it/s]
# epoch 3 training [time: 3.27s, train loss: 3006.9387]
# Saving current: saved/MultiVAE-Nov-27-2022_16-35-42.pth
# Train     4: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  1.86it/s]
# epoch 4 training [time: 3.78s, train loss: 2948.3442]
# Saving current: saved/MultiVAE-Nov-27-2022_16-35-42.pth
# Train     5: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.15it/s]
# epoch 5 training [time: 3.26s, train loss: 2916.9971]
# Saving current: saved/MultiVAE-Nov-27-2022_16-35-42.pth
# Train     6: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.14it/s]
# epoch 6 training [time: 3.28s, train loss: 2897.5956]
# Saving current: saved/MultiVAE-Nov-27-2022_16-35-42.pth
# Train     7: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.14it/s]
# epoch 7 training [time: 3.28s, train loss: 2884.9745]
# Saving current: saved/MultiVAE-Nov-27-2022_16-35-42.pth
# Train     8: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.13it/s]
# epoch 8 training [time: 3.29s, train loss: 2871.5185]
# Saving current: saved/MultiVAE-Nov-27-2022_16-35-42.pth
# Train     9: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.15it/s]
# epoch 9 training [time: 3.27s, train loss: 2851.2812]
# Saving current: saved/MultiVAE-Nov-27-2022_16-35-42.pth
# Loading model structure and parameters from saved/MultiVAE-Nov-27-2022_16-35-42.pth
# Evaluate   : 100%|███████████████████████████████████████████| 13354/13354 [00:22<00:00, 605.65it/s]
# best valid : None
# test result: OrderedDict([('recall@10', 0.084), ('mrr@10', 0.1695), ('ndcg@10', 0.0825), ('hit@10', 0.3503), ('precision@10', 0.0467)])
# It took 1.84 mins
# {'best_valid_score': -inf, 'valid_score_bigger': True, 'best_valid_result': None, 'test_result': OrderedDict([('recall@10', 0.084), ('mrr@10', 0.1695), ('ndcg@10', 0.0825), ('hit@10', 0.3503), ('precision@10', 0.0467)])}
# running MultiDAE...
# ['/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py', '-f', '/tmp/tmp4odlef17.json', '--HistoryManager.hist_file=:memory:']
#
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 10
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# mlp_hidden_size = [600]
# latent_dimension = 64
# dropout_prob = 0.5
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# device = cpu
# neg_sampling = None
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# Max value of user's history interaction records has reached 20.9471766848816% of the total.
# MultiDAE(
#   (encoder): MLPLayers(
#     (mlp_layers): Sequential(
#       (0): Dropout(p=0.0, inplace=False)
#       (1): Linear(in_features=3294, out_features=600, bias=True)
#       (2): Tanh()
#       (3): Dropout(p=0.0, inplace=False)
#       (4): Linear(in_features=600, out_features=64, bias=True)
#       (5): Tanh()
#     )
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=64, out_features=600, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=600, out_features=3294, bias=True)
#   )
# )
# Trainable parameters: 4034158
# FLOPs: 4029600.0
# Train     0: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  1.89it/s]
# epoch 0 training [time: 3.72s, train loss: 3248.4974]
# Saving current: saved/MultiDAE-Nov-27-2022_16-37-29.pth
# Train     1: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.13it/s]
# epoch 1 training [time: 3.30s, train loss: 3093.6642]
# Saving current: saved/MultiDAE-Nov-27-2022_16-37-29.pth
# Train     2: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.15it/s]
# epoch 2 training [time: 3.27s, train loss: 3038.2049]
# Saving current: saved/MultiDAE-Nov-27-2022_16-37-29.pth
# Train     3: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.17it/s]
# epoch 3 training [time: 3.24s, train loss: 2998.2585]
# Saving current: saved/MultiDAE-Nov-27-2022_16-37-29.pth
# Train     4: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.16it/s]
# epoch 4 training [time: 3.25s, train loss: 2949.4852]
# Saving current: saved/MultiDAE-Nov-27-2022_16-37-29.pth
# Train     5: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.17it/s]
# epoch 5 training [time: 3.24s, train loss: 2927.9619]
# Saving current: saved/MultiDAE-Nov-27-2022_16-37-29.pth
# Train     6: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.18it/s]
# epoch 6 training [time: 3.23s, train loss: 2902.7534]
# Saving current: saved/MultiDAE-Nov-27-2022_16-37-29.pth
# Train     7: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.18it/s]
# epoch 7 training [time: 3.22s, train loss: 2890.9279]
# Saving current: saved/MultiDAE-Nov-27-2022_16-37-29.pth
# Train     8: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.18it/s]
# epoch 8 training [time: 3.22s, train loss: 2882.6920]
# Saving current: saved/MultiDAE-Nov-27-2022_16-37-29.pth
# Train     9: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  1.98it/s]
# epoch 9 training [time: 3.55s, train loss: 2867.6552]
# Saving current: saved/MultiDAE-Nov-27-2022_16-37-29.pth
# Loading model structure and parameters from saved/MultiDAE-Nov-27-2022_16-37-29.pth
# Evaluate   : 100%|███████████████████████████████████████████| 13354/13354 [00:20<00:00, 644.82it/s]
# best valid : None
# test result: OrderedDict([('recall@10', 0.0829), ('mrr@10', 0.1655), ('ndcg@10', 0.081), ('hit@10', 0.3438), ('precision@10', 0.0459)])
# It took 1.76 mins
# {'best_valid_score': -inf, 'valid_score_bigger': True, 'best_valid_result': None, 'test_result': OrderedDict([('recall@10', 0.0829), ('mrr@10', 0.1655), ('ndcg@10', 0.081), ('hit@10', 0.3438), ('precision@10', 0.0459)])}
# running MacridVAE...
# ['/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py', '-f', '/tmp/tmp4odlef17.json', '--HistoryManager.hist_file=:memory:']
#
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 10
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# dropout_prob = 0.5
# kfac = 10
# nogb = False
# std = 0.01
# encoder_hidden_size = [600]
# tau = 0.1
# anneal_cap = 0.2
# total_anneal_steps = 200000
# reg_weights = [0.0, 0.0]
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# device = cpu
# neg_sampling = None
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# Max value of user's history interaction records has reached 20.9471766848816% of the total.
# MacridVAE(
#   (encoder): Sequential(
#     (0): Linear(in_features=3294, out_features=600, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=600, out_features=128, bias=True)
#   )
#   (item_embedding): Embedding(3294, 64)
#   (k_embedding): Embedding(10, 64)
#   (l2_loss): EmbLoss()
# )
# Trainable parameters: 2265384
# FLOPs: 20532000.0
# Train     0: 100%|████████████████████████████████████████████████████| 7/7 [00:27<00:00,  3.99s/it]
# epoch 0 training [time: 28.06s, train loss: 3199.9340]
# Saving current: saved/MacridVAE-Nov-27-2022_16-39-13.pth
# Train     1: 100%|████████████████████████████████████████████████████| 7/7 [00:25<00:00,  3.68s/it]
# epoch 1 training [time: 25.80s, train loss: 2841.0144]
# Saving current: saved/MacridVAE-Nov-27-2022_16-39-13.pth
# Train     2: 100%|████████████████████████████████████████████████████| 7/7 [00:27<00:00,  3.96s/it]
# epoch 2 training [time: 27.77s, train loss: 2745.4806]
# Saving current: saved/MacridVAE-Nov-27-2022_16-39-13.pth
# Train     3: 100%|████████████████████████████████████████████████████| 7/7 [00:27<00:00,  3.87s/it]
# epoch 3 training [time: 27.14s, train loss: 2692.4230]
# Saving current: saved/MacridVAE-Nov-27-2022_16-39-13.pth
# Train     4: 100%|████████████████████████████████████████████████████| 7/7 [00:27<00:00,  3.88s/it]
# epoch 4 training [time: 27.30s, train loss: 2652.6273]
# Saving current: saved/MacridVAE-Nov-27-2022_16-39-13.pth
# Train     5: 100%|████████████████████████████████████████████████████| 7/7 [00:27<00:00,  3.86s/it]
# epoch 5 training [time: 27.12s, train loss: 2629.0800]
# Saving current: saved/MacridVAE-Nov-27-2022_16-39-13.pth
# Train     6: 100%|████████████████████████████████████████████████████| 7/7 [00:27<00:00,  3.98s/it]
# epoch 6 training [time: 27.85s, train loss: 2608.0349]
# Saving current: saved/MacridVAE-Nov-27-2022_16-39-13.pth
# Train     7: 100%|████████████████████████████████████████████████████| 7/7 [00:26<00:00,  3.80s/it]
# epoch 7 training [time: 26.65s, train loss: 2591.5298]
# Saving current: saved/MacridVAE-Nov-27-2022_16-39-13.pth
# Train     8: 100%|████████████████████████████████████████████████████| 7/7 [00:26<00:00,  3.74s/it]
# epoch 8 training [time: 26.19s, train loss: 2579.7921]
# Saving current: saved/MacridVAE-Nov-27-2022_16-39-13.pth
# Train     9: 100%|████████████████████████████████████████████████████| 7/7 [00:26<00:00,  3.79s/it]
# epoch 9 training [time: 26.56s, train loss: 2567.7705]
# Saving current: saved/MacridVAE-Nov-27-2022_16-39-13.pth
# Loading model structure and parameters from saved/MacridVAE-Nov-27-2022_16-39-13.pth
# Evaluate   : 100%|███████████████████████████████████████████| 13354/13354 [02:07<00:00, 104.66it/s]
# best valid : None
# test result: OrderedDict([('recall@10', 0.0836), ('mrr@10', 0.1563), ('ndcg@10', 0.0784), ('hit@10', 0.3504), ('precision@10', 0.0458)])
# It took 7.47 mins
# {'best_valid_score': -inf, 'valid_score_bigger': True, 'best_valid_result': None, 'test_result': OrderedDict([('recall@10', 0.0836), ('mrr@10', 0.1563), ('ndcg@10', 0.0784), ('hit@10', 0.3504), ('precision@10', 0.0458)])}
# running NeuMF...
# ['/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py', '-f', '/tmp/tmp4odlef17.json', '--HistoryManager.hist_file=:memory:']
#
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 10
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# mf_embedding_size = 64
# mlp_embedding_size = 64
# mlp_hidden_size = [128, 64]
# dropout_prob = 0.1
# mf_train = True
# mlp_train = True
# use_pretrain = False
# mf_pretrain_path = None
# mlp_pretrain_path = None
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# device = cpu
# neg_sampling = None
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# NeuMF(
#   (user_mf_embedding): Embedding(13355, 64)
#   (item_mf_embedding): Embedding(3294, 64)
#   (user_mlp_embedding): Embedding(13355, 64)
#   (item_mlp_embedding): Embedding(3294, 64)
#   (mlp_layers): MLPLayers(
#     (mlp_layers): Sequential(
#       (0): Dropout(p=0.1, inplace=False)
#       (1): Linear(in_features=128, out_features=128, bias=True)
#       (2): ReLU()
#       (3): Dropout(p=0.1, inplace=False)
#       (4): Linear(in_features=128, out_features=64, bias=True)
#       (5): ReLU()
#     )
#   )
#   (predict_layer): Linear(in_features=128, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
#   (loss): BCEWithLogitsLoss()
# )
# Trainable parameters: 2155969
# FLOPs: 24960.0
# Train     0: 100%|████████████████████████████████████████████████| 755/755 [00:29<00:00, 25.90it/s]
# epoch 0 training [time: 29.17s, train loss: 425.6783]
# Saving current: saved/NeuMF-Nov-27-2022_16-46-40.pth
# Train     1: 100%|████████████████████████████████████████████████| 755/755 [00:28<00:00, 26.23it/s]
# epoch 1 training [time: 28.80s, train loss: 361.1044]
# Saving current: saved/NeuMF-Nov-27-2022_16-46-40.pth
# Train     2: 100%|████████████████████████████████████████████████| 755/755 [00:29<00:00, 25.92it/s]
# epoch 2 training [time: 29.15s, train loss: 317.1835]
# Saving current: saved/NeuMF-Nov-27-2022_16-46-40.pth
# Train     3: 100%|████████████████████████████████████████████████| 755/755 [00:29<00:00, 25.84it/s]
# epoch 3 training [time: 29.24s, train loss: 288.6900]
# Saving current: saved/NeuMF-Nov-27-2022_16-46-40.pth
# Train     4: 100%|████████████████████████████████████████████████| 755/755 [00:29<00:00, 25.94it/s]
# epoch 4 training [time: 29.13s, train loss: 267.5104]
# Saving current: saved/NeuMF-Nov-27-2022_16-46-40.pth
# Train     5: 100%|████████████████████████████████████████████████| 755/755 [00:28<00:00, 26.46it/s]
# epoch 5 training [time: 28.56s, train loss: 249.3377]
# Saving current: saved/NeuMF-Nov-27-2022_16-46-40.pth
# Train     6: 100%|████████████████████████████████████████████████| 755/755 [00:28<00:00, 26.20it/s]
# epoch 6 training [time: 28.84s, train loss: 233.4761]
# Saving current: saved/NeuMF-Nov-27-2022_16-46-40.pth
# Train     7: 100%|████████████████████████████████████████████████| 755/755 [00:29<00:00, 25.92it/s]
# epoch 7 training [time: 29.15s, train loss: 218.8789]
# Saving current: saved/NeuMF-Nov-27-2022_16-46-40.pth
# Train     8: 100%|████████████████████████████████████████████████| 755/755 [00:29<00:00, 25.91it/s]
# epoch 8 training [time: 29.16s, train loss: 205.8908]
# Saving current: saved/NeuMF-Nov-27-2022_16-46-40.pth
# Train     9: 100%|████████████████████████████████████████████████| 755/755 [00:29<00:00, 25.98it/s]
# epoch 9 training [time: 29.08s, train loss: 195.0840]
# Saving current: saved/NeuMF-Nov-27-2022_16-46-40.pth
# Loading model structure and parameters from saved/NeuMF-Nov-27-2022_16-46-40.pth
# Evaluate   : 100%|███████████████████████████████████████████| 13354/13354 [00:49<00:00, 271.51it/s]
# best valid : None
# test result: OrderedDict([('recall@10', 0.0693), ('mrr@10', 0.1169), ('ndcg@10', 0.0606), ('hit@10', 0.3019), ('precision@10', 0.0382)])
# It took 6.47 mins
# {'best_valid_score': -inf, 'valid_score_bigger': True, 'best_valid_result': None, 'test_result': OrderedDict([('recall@10', 0.0693), ('mrr@10', 0.1169), ('ndcg@10', 0.0606), ('hit@10', 0.3019), ('precision@10', 0.0382)])}
# running RecVAE...
# ['/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py', '-f', '/tmp/tmp4odlef17.json', '--HistoryManager.hist_file=:memory:']
#
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 10
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# hidden_dimension = 600
# latent_dimension = 200
# dropout_prob = 0.5
# beta = 0.2
# gamma = 0.005
# mixture_weights = [0.15, 0.75, 0.1]
# n_enc_epochs = 3
# n_dec_epochs = 1
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# device = cpu
# neg_sampling = None
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# Max value of user's history interaction records has reached 20.9471766848816% of the total.
# RecVAE(
#   (encoder): Encoder(
#     (fc1): Linear(in_features=3294, out_features=600, bias=True)
#     (ln1): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#     (fc2): Linear(in_features=600, out_features=600, bias=True)
#     (ln2): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#     (fc3): Linear(in_features=600, out_features=600, bias=True)
#     (ln3): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#     (fc4): Linear(in_features=600, out_features=600, bias=True)
#     (ln4): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#     (fc5): Linear(in_features=600, out_features=600, bias=True)
#     (ln5): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#     (fc_mu): Linear(in_features=600, out_features=200, bias=True)
#     (fc_logvar): Linear(in_features=600, out_features=200, bias=True)
#   )
#   (prior): CompositePrior(
#     (encoder_old): Encoder(
#       (fc1): Linear(in_features=3294, out_features=600, bias=True)
#       (ln1): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#       (fc2): Linear(in_features=600, out_features=600, bias=True)
#       (ln2): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#       (fc3): Linear(in_features=600, out_features=600, bias=True)
#       (ln3): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#       (fc4): Linear(in_features=600, out_features=600, bias=True)
#       (ln4): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#       (fc5): Linear(in_features=600, out_features=600, bias=True)
#       (ln5): LayerNorm((600,), eps=0.1, elementwise_affine=True)
#       (fc_mu): Linear(in_features=600, out_features=200, bias=True)
#       (fc_logvar): Linear(in_features=600, out_features=200, bias=True)
#     )
#   )
#   (decoder): Linear(in_features=200, out_features=3294, bias=True)
# )
# Trainable parameters: 4327894
# FLOPs: 4321200.0
# Train     0: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.20it/s]
# Train     0: 100%|████████████████████████████████████████████████████| 7/7 [00:06<00:00,  1.12it/s]
# Train     0: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.22it/s]
# Train     0: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.24it/s]
# epoch 0 training [time: 23.51s, train loss: 2353.6621]
# Saving current: saved/RecVAE-Nov-27-2022_16-53-08.pth
# Train     1: 100%|████████████████████████████████████████████████████| 7/7 [00:06<00:00,  1.10it/s]
# Train     1: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.20it/s]
# Train     1: 100%|████████████████████████████████████████████████████| 7/7 [00:06<00:00,  1.14it/s]
# Train     1: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.27it/s]
# epoch 1 training [time: 23.93s, train loss: 2244.7567]
# Saving current: saved/RecVAE-Nov-27-2022_16-53-08.pth
# Train     2: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.23it/s]
# Train     2: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.25it/s]
# Train     2: 100%|████████████████████████████████████████████████████| 7/7 [00:06<00:00,  1.13it/s]
# Train     2: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.28it/s]
# epoch 2 training [time: 23.04s, train loss: 2184.6202]
# Saving current: saved/RecVAE-Nov-27-2022_16-53-08.pth
# Train     3: 100%|████████████████████████████████████████████████████| 7/7 [00:06<00:00,  1.14it/s]
# Train     3: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.25it/s]
# Train     3: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.23it/s]
# Train     3: 100%|████████████████████████████████████████████████████| 7/7 [00:06<00:00,  1.15it/s]
# epoch 3 training [time: 23.66s, train loss: 2145.9091]
# Saving current: saved/RecVAE-Nov-27-2022_16-53-08.pth
# Train     4: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.23it/s]
# Train     4: 100%|████████████████████████████████████████████████████| 7/7 [00:06<00:00,  1.13it/s]
# Train     4: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.25it/s]
# Train     4: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.27it/s]
# epoch 4 training [time: 23.09s, train loss: 2107.9065]
# Saving current: saved/RecVAE-Nov-27-2022_16-53-08.pth
# Train     5: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.18it/s]
# Train     5: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.18it/s]
# Train     5: 100%|████████████████████████████████████████████████████| 7/7 [00:06<00:00,  1.16it/s]
# Train     5: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.23it/s]
# epoch 5 training [time: 23.70s, train loss: 2075.3962]
# Saving current: saved/RecVAE-Nov-27-2022_16-53-08.pth
# Train     6: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.24it/s]
# Train     6: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.23it/s]
# Train     6: 100%|████████████████████████████████████████████████████| 7/7 [00:06<00:00,  1.10it/s]
# Train     6: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.24it/s]
# epoch 6 training [time: 23.44s, train loss: 2044.5482]
# Saving current: saved/RecVAE-Nov-27-2022_16-53-08.pth
# Train     7: 100%|████████████████████████████████████████████████████| 7/7 [00:06<00:00,  1.12it/s]
# Train     7: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.21it/s]
# Train     7: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.21it/s]
# Train     7: 100%|████████████████████████████████████████████████████| 7/7 [00:06<00:00,  1.11it/s]
# epoch 7 training [time: 24.20s, train loss: 2016.3134]
# Saving current: saved/RecVAE-Nov-27-2022_16-53-08.pth
# Train     8: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.20it/s]
# Train     8: 100%|████████████████████████████████████████████████████| 7/7 [00:06<00:00,  1.11it/s]
# Train     8: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.23it/s]
# Train     8: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.27it/s]
# epoch 8 training [time: 23.42s, train loss: 2000.3300]
# Saving current: saved/RecVAE-Nov-27-2022_16-53-08.pth
# Train     9: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.21it/s]
# Train     9: 100%|████████████████████████████████████████████████████| 7/7 [00:06<00:00,  1.13it/s]
# Train     9: 100%|████████████████████████████████████████████████████| 7/7 [00:06<00:00,  1.10it/s]
# Train     9: 100%|████████████████████████████████████████████████████| 7/7 [00:05<00:00,  1.26it/s]
# epoch 9 training [time: 24.02s, train loss: 1979.2943]
# Saving current: saved/RecVAE-Nov-27-2022_16-53-08.pth
# Loading model structure and parameters from saved/RecVAE-Nov-27-2022_16-53-08.pth
# Evaluate   : 100%|███████████████████████████████████████████| 13354/13354 [00:26<00:00, 495.25it/s]
# best valid : None
# test result: OrderedDict([('recall@10', 0.0849), ('mrr@10', 0.1697), ('ndcg@10', 0.0828), ('hit@10', 0.3532), ('precision@10', 0.047)])
# It took 5.19 mins
# {'best_valid_score': -inf, 'valid_score_bigger': True, 'best_valid_result': None, 'test_result': OrderedDict([('recall@10', 0.0849), ('mrr@10', 0.1697), ('ndcg@10', 0.0828), ('hit@10', 0.3532), ('precision@10', 0.047)])}
# running RepeatNet...
# ['/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py', '-f', '/tmp/tmp4odlef17.json', '--HistoryManager.hist_file=:memory:']
#
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 10
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}
# repeatable = True
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# embedding_size = 64
# hidden_size = 64
# joint_train = False
# dropout_prob = 0.5
# loss_type = CE
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.SEQUENTIAL
# device = cpu
# neg_sampling = None
# MODEL_INPUT_TYPE = InputType.POINTWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# RepeatNet(
#   (item_matrix): Embedding(3294, 64, padding_idx=0)
#   (gru): GRU(64, 64, batch_first=True)
#   (repeat_explore_mechanism): Repeat_Explore_Mechanism(
#     (dropout): Dropout(p=0.5, inplace=False)
#     (Wre): Linear(in_features=64, out_features=64, bias=False)
#     (Ure): Linear(in_features=64, out_features=64, bias=False)
#     (tanh): Tanh()
#     (Vre): Linear(in_features=64, out_features=1, bias=False)
#     (Wcre): Linear(in_features=64, out_features=2, bias=False)
#   )
#   (repeat_recommendation_decoder): Repeat_Recommendation_Decoder(
#     (dropout): Dropout(p=0.5, inplace=False)
#     (Wr): Linear(in_features=64, out_features=64, bias=False)
#     (Ur): Linear(in_features=64, out_features=64, bias=False)
#     (tanh): Tanh()
#     (Vr): Linear(in_features=64, out_features=1, bias=True)
#   )
#   (explore_recommendation_decoder): Explore_Recommendation_Decoder(
#     (dropout): Dropout(p=0.5, inplace=False)
#     (We): Linear(in_features=64, out_features=64, bias=True)
#     (Ue): Linear(in_features=64, out_features=64, bias=True)
#     (tanh): Tanh()
#     (Ve): Linear(in_features=64, out_features=1, bias=True)
#     (matrix_for_explore): Linear(in_features=128, out_features=3294, bias=False)
#   )
# )
# Trainable parameters: 682434
# FLOPs: 2331648.0
# Train     0: 100%|████████████████████████████████████████████████| 743/743 [42:30<00:00,  3.43s/it]
# epoch 0 training [time: 2550.95s, train loss: 5955.3650]
# Saving current: saved/RepeatNet-Nov-27-2022_16-58-29.pth
# Train     1: 100%|████████████████████████████████████████████████| 743/743 [43:05<00:00,  3.48s/it]
# epoch 1 training [time: 2585.55s, train loss: 5903.5382]
# Saving current: saved/RepeatNet-Nov-27-2022_16-58-29.pth
# Train     2: 100%|████████████████████████████████████████████████| 743/743 [42:27<00:00,  3.43s/it]
# epoch 2 training [time: 2547.68s, train loss: 5883.7726]
# Saving current: saved/RepeatNet-Nov-27-2022_16-58-29.pth
# Train     3: 100%|████████████████████████████████████████████████| 743/743 [42:56<00:00,  3.47s/it]
# epoch 3 training [time: 2576.73s, train loss: 5871.1523]
# Saving current: saved/RepeatNet-Nov-27-2022_16-58-29.pth
# Train     4: 100%|████████████████████████████████████████████████| 743/743 [43:14<00:00,  3.49s/it]
# epoch 4 training [time: 2595.02s, train loss: 5861.7956]
# Saving current: saved/RepeatNet-Nov-27-2022_16-58-29.pth
# Train     5: 100%|████████████████████████████████████████████████| 743/743 [42:57<00:00,  3.47s/it]
# epoch 5 training [time: 2577.36s, train loss: 5854.3181]
# Saving current: saved/RepeatNet-Nov-27-2022_16-58-29.pth
# Train     6: 100%|████████████████████████████████████████████████| 743/743 [43:00<00:00,  3.47s/it]
# epoch 6 training [time: 2580.45s, train loss: 5847.4086]
# Saving current: saved/RepeatNet-Nov-27-2022_16-58-29.pth
# Train     7: 100%|████████████████████████████████████████████████| 743/743 [43:05<00:00,  3.48s/it]
# epoch 7 training [time: 2585.33s, train loss: 5842.5805]
# Saving current: saved/RepeatNet-Nov-27-2022_16-58-29.pth
# Train     8: 100%|████████████████████████████████████████████████| 743/743 [43:05<00:00,  3.48s/it]
# epoch 8 training [time: 2585.23s, train loss: 5838.5373]
# Saving current: saved/RepeatNet-Nov-27-2022_16-58-29.pth
# Train     9: 100%|████████████████████████████████████████████████| 743/743 [43:13<00:00,  3.49s/it]
# epoch 9 training [time: 2593.18s, train loss: 5833.5700]
# Saving current: saved/RepeatNet-Nov-27-2022_16-58-29.pth
# Loading model structure and parameters from saved/RepeatNet-Nov-27-2022_16-58-29.pth
# Evaluate   : 100%|██████████████████████████████████████████████████| 20/20 [01:01<00:00,  3.06s/it]
# best valid : None
# test result: OrderedDict([('recall@10', 0.1364), ('mrr@10', 0.0584), ('ndcg@10', 0.0766), ('hit@10', 0.1364), ('precision@10', 0.0136)])
# It took 431.60 mins
# {'best_valid_score': -inf, 'valid_score_bigger': True, 'best_valid_result': None, 'test_result': OrderedDict([('recall@10', 0.1364), ('mrr@10', 0.0584), ('ndcg@10', 0.0766), ('hit@10', 0.1364), ('precision@10', 0.0136)])}
# CPU times: user 11h 6min 5s, sys: 3h 33min 37s, total: 14h 39min 43s
# Wall time: 7h 34min 19s

# %%
result = run_recbole(model='MultiVAE', dataset = 'recbox_data',config_dict = parameter_dict )
# Out:
# ['/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py', '-f', '/tmp/tmp4odlef17.json', '--HistoryManager.hist_file=:memory:']
#
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = recbox_data
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 10
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# eval_args = {'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}
# repeatable = False
# metrics = ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
# topk = [10]
# valid_metric = MRR@10
# valid_metric_bigger = True
# eval_batch_size = 4096
# metric_decimal_place = 4
#
# Dataset Hyper Parameters:
# field_separator =
# seq_separator =
# USER_ID_FIELD = user_id
# ITEM_ID_FIELD = item_id
# RATING_FIELD = rating
# TIME_FIELD = timestamp
# seq_len = None
# LABEL_FIELD = label
# threshold = None
# NEG_PREFIX = neg_
# load_col = {'inter': ['user_id', 'item_id', 'timestamp']}
# unload_col = None
# unused_col = None
# additional_feat_suffix = None
# rm_dup_inter = None
# val_interval = None
# filter_inter_by_user_or_item = True
# user_inter_num_interval = [40,inf)
# item_inter_num_interval = [40,inf)
# alias_of_user_id = None
# alias_of_item_id = None
# alias_of_entity_id = None
# alias_of_relation_id = None
# preload_weight = None
# normalize_field = None
# normalize_all = None
# ITEM_LIST_LENGTH_FIELD = item_length
# LIST_SUFFIX = _list
# MAX_ITEM_LIST_LENGTH = 50
# POSITION_FIELD = position_id
# HEAD_ENTITY_ID_FIELD = head_id
# TAIL_ENTITY_ID_FIELD = tail_id
# RELATION_ID_FIELD = relation_id
# ENTITY_ID_FIELD = entity_id
# benchmark_filename = None
#
# Other Hyper Parameters:
# worker = 0
# wandb_project = recbole
# shuffle = True
# require_pow = False
# enable_amp = False
# enable_scaler = False
# transform = None
# mlp_hidden_size = [600]
# latent_dimension = 128
# dropout_prob = 0.5
# anneal_cap = 0.2
# total_anneal_steps = 200000
# numerical_features = []
# discretization = None
# kg_reverse_r = False
# entity_kg_num_interval = [0,inf)
# relation_kg_num_interval = [0,inf)
# MODEL_TYPE = ModelType.GENERAL
# device = cpu
# neg_sampling = None
# MODEL_INPUT_TYPE = InputType.PAIRWISE
# eval_type = EvaluatorType.RANKING
# single_spec = True
# local_rank = 0
# eval_neg_sample_args = {'distribution': 'uniform', 'sample_num': 'none'}
#
#
# recbox_data
# The number of users: 13355
# Average actions of users: 63.815710648494836
# The number of items: 3294
# Average actions of items: 258.78985727300335
# The number of inters: 852195
# The sparsity of the dataset: 98.06281322904924%
# Remain Fields: ['user_id', 'item_id', 'timestamp']
# [Training]: train_batch_size = [2048] train_neg_sample_args: [{'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}]
# [Evaluation]: eval_batch_size = [4096] eval_args: [{'split': {'RS': [9, 0, 1]}, 'group_by': 'user', 'order': 'TO', 'mode': 'full'}]
# Max value of user's history interaction records has reached 20.9471766848816% of the total.
# MultiVAE(
#   (encoder): Sequential(
#     (0): Linear(in_features=3294, out_features=600, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=600, out_features=128, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=64, out_features=600, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=600, out_features=3294, bias=True)
#   )
# )
# Trainable parameters: 4072622
# FLOPs: 4068000.0
# Train     0: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.14it/s]
# epoch 0 training [time: 3.29s, train loss: 3249.5872]
# Saving current: saved/MultiVAE-Nov-28-2022_00-10-04.pth
# Train     1: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.08it/s]
# epoch 1 training [time: 3.39s, train loss: 3098.8139]
# Saving current: saved/MultiVAE-Nov-28-2022_00-10-04.pth
# Train     2: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.07it/s]
# epoch 2 training [time: 3.40s, train loss: 3044.8109]
# Saving current: saved/MultiVAE-Nov-28-2022_00-10-04.pth
# Train     3: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.10it/s]
# epoch 3 training [time: 3.36s, train loss: 3006.9387]
# Saving current: saved/MultiVAE-Nov-28-2022_00-10-04.pth
# Train     4: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.10it/s]
# epoch 4 training [time: 3.36s, train loss: 2948.3442]
# Saving current: saved/MultiVAE-Nov-28-2022_00-10-04.pth
# Train     5: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  1.85it/s]
# epoch 5 training [time: 3.82s, train loss: 2916.9971]
# Saving current: saved/MultiVAE-Nov-28-2022_00-10-04.pth
# Train     6: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.15it/s]
# epoch 6 training [time: 3.28s, train loss: 2897.5956]
# Saving current: saved/MultiVAE-Nov-28-2022_00-10-04.pth
# Train     7: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.12it/s]
# epoch 7 training [time: 3.34s, train loss: 2884.9745]
# Saving current: saved/MultiVAE-Nov-28-2022_00-10-04.pth
# Train     8: 100%|████████████████████████████████████████████████████| 7/7 [00:04<00:00,  1.52it/s]
# epoch 8 training [time: 4.63s, train loss: 2871.5185]
# Saving current: saved/MultiVAE-Nov-28-2022_00-10-04.pth
# Train     9: 100%|████████████████████████████████████████████████████| 7/7 [00:03<00:00,  2.11it/s]
# epoch 9 training [time: 3.34s, train loss: 2851.2812]
# Saving current: saved/MultiVAE-Nov-28-2022_00-10-04.pth
# Loading model structure and parameters from saved/MultiVAE-Nov-28-2022_00-10-04.pth
# Evaluate   : 100%|███████████████████████████████████████████| 13354/13354 [00:22<00:00, 583.70it/s]
# best valid : None
# test result: OrderedDict([('recall@10', 0.084), ('mrr@10', 0.1695), ('ndcg@10', 0.0825), ('hit@10', 0.3503), ('precision@10', 0.0467)])
